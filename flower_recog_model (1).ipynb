# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
#data preprocessing

# %%
#traning image processing

# %%
train_datagen = ImageDataGenerator(
                rescale=1./255,
                shear_range=0.2,
                zoom_range=0.2,
                horizontal_flip=True)
training_set = train_datagen.flow_from_directory(
               '/content/drive/MyDrive/flower_recognition..model/training_set',
               target_size=(64,64),
               batch_size=32,
               class_mode='categorical')
# Out:
# Found 4468 images belonging to 5 classes.

# %%
#test image processing

# %%
test_datagen = ImageDataGenerator(rescale=1./255)
test_set = test_datagen.flow_from_directory('/content/drive/MyDrive/flower_recognition..model/test_set',
                         target_size=(64, 64),
                         batch_size=32,
                         class_mode='categorical')
# Out:
# Found 448 images belonging to 5 classes.

# %%
#building model

# %%
cnn = tf.keras.models.Sequential()

# %%
#building convolution layer

# %%
cnn.add(tf.keras.layers.Conv2D(filters=64,kernel_size=3,activation='relu',input_shape=[64,64,3]))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2,strides=2))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
cnn.add(tf.keras.layers.Conv2D(filters=64,kernel_size=3,activation='relu',input_shape=[64,64,3]))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2,strides=2))

# %%
cnn.add(tf.keras.layers.Dropout(0.5))

# %%
cnn.add(tf.keras.layers.Flatten())

# %%
cnn.add(tf.keras.layers.Dense(units=128,activation='relu'))

# %%
cnn.add(tf.keras.layers.Dense(units=5,activation='softmax'))

# %%
cnn.compile(optimizer='rmsprop',loss='categorical_crossentropy',metrics=['accuracy'])

# %%
cnn.fit(x=training_set, validation_data=test_set, epochs=30)
# Out:
# Epoch 1/30
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1182s 8s/step - accuracy: 0.4573 - loss: 1.3276 - val_accuracy: 0.5759 - val_loss: 1.0611
# Epoch 2/30
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 75s 535ms/step - accuracy: 0.5812 - loss: 1.0625 - val_accuracy: 0.6384 - val_loss: 0.9055
# Epoch 3/30
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 74s 528ms/step - accuracy: 0.6321 - loss: 0.9579 - val_accuracy: 0.7076 - val_loss: 0.8138
# Epoch 4/30
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 71s 510ms/step - accuracy: 0.6526 - loss: 0.8847 - val_accuracy: 0.6875 - val_loss: 0.8287
# Epoch 5/30
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 84s 526ms/step - accuracy: 0.6824 - loss: 0.8327 - val_accuracy: 0.7031 - val_loss: 0.7764
# Epoch 6/30
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 77s 548ms/step - accuracy: 0.6974 - loss: 0.7949 - val_accuracy: 0.7478 - val_loss: 0.7107
# Epoch 7/30
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 73s 518ms/step - accuracy: 0.7128 - loss: 0.7452 - val_accuracy: 0.7790 - val_loss: 0.6623
# Epoch 8/30
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 75s 532ms/step - accuracy: 0.7283 - loss: 0.7190 - val_accuracy: 0.7567 - val_loss: 0.6524
# Epoch 9/30
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 74s 525ms/step - accuracy: 0.7377 - loss: 0.6889 - val_accuracy: 0.6808 - val_loss: 0.8191
# Epoch 10/30
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 73s 518ms/step - accuracy: 0.7462 - loss: 0.6642 - val_accuracy: 0.8013 - val_loss: 0.5571
# Epoch 11/30
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 75s 536ms/step - accuracy: 0.7610 - loss: 0.6386 - val_accuracy: 0.8080 - val_loss: 0.5513
# Epoch 12/30
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 74s 529ms/step - accuracy: 0.7641 - loss: 0.6183 - val_accuracy: 0.8036 - val_loss: 0.5271
# Epoch 13/30
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 72s 512ms/step - accuracy: 0.7726 - loss: 0.6126 - val_accuracy: 0.7679 - val_loss: 0.6201
# Epoch 14/30
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 73s 517ms/step - accuracy: 0.7874 - loss: 0.5754 - val_accuracy: 0.8326 - val_loss: 0.4931
# Epoch 15/30
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 74s 527ms/step - accuracy: 0.7945 - loss: 0.5504 - val_accuracy: 0.8237 - val_loss: 0.5095
# Epoch 16/30
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 74s 527ms/step - accuracy: 0.8064 - loss: 0.5215 - val_accuracy: 0.8259 - val_loss: 0.4710
# Epoch 17/30
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 73s 516ms/step - accuracy: 0.8057 - loss: 0.5151 - val_accuracy: 0.8996 - val_loss: 0.3718
# Epoch 18/30
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 75s 533ms/step - accuracy: 0.8162 - loss: 0.4879 - val_accuracy: 0.8817 - val_loss: 0.3440
# Epoch 19/30
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 73s 519ms/step - accuracy: 0.8149 - loss: 0.4969 - val_accuracy: 0.8661 - val_loss: 0.3450
# Epoch 20/30
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 82s 518ms/step - accuracy: 0.8252 - loss: 0.4654 - val_accuracy: 0.8906 - val_loss: 0.3471
# Epoch 21/30
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 72s 517ms/step - accuracy: 0.8395 - loss: 0.4463 - val_accuracy: 0.8951 - val_loss: 0.3309
# Epoch 22/30
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 72s 512ms/step - accuracy: 0.8342 - loss: 0.4489 - val_accuracy: 0.8549 - val_loss: 0.3954
# Epoch 23/30
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 73s 522ms/step - accuracy: 0.8516 - loss: 0.4108 - val_accuracy: 0.9129 - val_loss: 0.2729
# Epoch 24/30
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 70s 503ms/step - accuracy: 0.8527 - loss: 0.4036 - val_accuracy: 0.8438 - val_loss: 0.4276
# Epoch 25/30
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 86s 530ms/step - accuracy: 0.8588 - loss: 0.3903 - val_accuracy: 0.8772 - val_loss: 0.3254
# Epoch 26/30
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 72s 515ms/step - accuracy: 0.8588 - loss: 0.3725 - val_accuracy: 0.8996 - val_loss: 0.2792
# Epoch 27/30
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 70s 497ms/step - accuracy: 0.8615 - loss: 0.3731 - val_accuracy: 0.9353 - val_loss: 0.2367
# Epoch 28/30
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 72s 513ms/step - accuracy: 0.8753 - loss: 0.3505 - val_accuracy: 0.9397 - val_loss: 0.2086
# Epoch 29/30
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 72s 513ms/step - accuracy: 0.8818 - loss: 0.3422 - val_accuracy: 0.9241 - val_loss: 0.2488
# Epoch 30/30
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 82s 515ms/step - accuracy: 0.8818 - loss: 0.3225 - val_accuracy: 0.9330 - val_loss: 0.2358

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#preprocess new image

# %%
from keras.preprocessing import image
test_image = image.load_img('/content/drive/MyDrive/flower_recognition..model/prediction/dandalion.jpg',target_size=(64,64))
test_image = np.expand_dims(test_image,axis=0)
result = cnn.predict(test_image)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step

# %%
training_set.class_indices
# Out:
# {'daisy': 0, 'dandelion': 1, 'roses': 2, 'sunflower': 3, 'tulip': 4}

# %%
print(result)
# Out:
# [[1. 0. 0. 0. 0.]]

# %%
if result[0][0]==1:
    print('Daisy')
elif result[0][1]==1:
      print('dandeleion')
elif result[0][2]==1:
       print('roses')
elif result[0][3]==1:
        print('sunflower')
elif result[0][4]==1:
        print('tulip')
# Out:
# Daisy
